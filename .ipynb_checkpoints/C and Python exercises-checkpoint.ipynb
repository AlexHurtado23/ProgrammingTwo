# %% [markdown]
# # C and Python exercises
#
# ### Team Data 2A:
#
# [Emmanuel Alejandro Hurtado Alejandre](https://github.com/AlexHurtado23/ProgrammingTwo)
#
# [Adriana Maribel Ku Huchim](https://github.com/Adriana-ku06/programming2)
#
# [Pedro Alejandro Uicab Díaz](https://github.com/PedroAlejandroUicabDiaz/UNIT1_DATOS_2A.git)
#
# ___
#
# ## C exercises
#
# ### 1. Write a program to input any character and check whether it is alphabet, digit or special character.
#
# ~~~
# #include <stdio.h>
# #include <ctype.h>
# int main(void)
# {
#   char caracter;
#   printf("Write a character:\n");
#   scanf("%c", &caracter);
#   if (isalpha(caracter)) {// isalpha lets you know if it is a letter
#     printf("It is a letter of the alphabet");
#   }
#
#   else {
#
#     if(isdigit(caracter)){// isdigit lets you know if it is a number
#       printf("It is  a number");
#     }
#     else{
#     printf("It is a special character");}
#   }
#   return 0;
# }
# ~~~
#
# ### 2. Write a program to check whether a number is even or odd.
# ~~~
# #include <stdio.h>
#
# int main(){
#
#     int num;
#
#     printf("Give me a number: ");//getting a number to evaluate it
#     scanf("%d",&num);
#
#     printf("\n");
#
#     if(num % 2 == 0){ //Evaluating  if the residue of the number divided by 2 is 0. if it is, number is even
#         printf("The number %d is Even\n",num);
#     }
#     else{ //If the residue of number is not 0, it is odd
#         printf("The number %d is Odd\n",num);
#     }
#
# return 0;
# }
# ~~~
#
# ### 3. Write a program to find maximum between three numbers.
# ~~~
# #include <stdio.h>
#
# int main(){
# int n1,n2,n3;
# int temp;
#
# printf("Enter first number: "); scanf("%d",&n1);
# printf("Enter second number: "); scanf("%d",&n2);
# printf("Enter third number: "); scanf("%d",&n3);
#
# if(n1>n2){
#   if(n1>n3){
#     temp=n1;
#     printf("The maximum number is %d",temp);
#   }
# }
# else{
#   if (n2>n3){
#     temp=n2;
#     printf("The maximum number is %d",temp);
#   }
#   else{
#     temp=n3;
#     printf("The maximum number is %d",temp);
#   }
# }
#   return 0;
# }
# ~~~
#
# ### 4. Write a program to play "Paper, Rock or Scissors".
# ~~~
# #include <stdio.h>
# #include <stdlib.h>
# #include <string.h>
# // juego de piedra papel y tijera contra la computadora
#
# int juego(int x, int num){
#
#   char *jugador;
#   char *computadora;
# ////////////////////////////
# /*assign value to player*/
#
# switch (x) {
#     case 1:  jugador="piedra"; break;
#     case 2:  jugador="papel"; break;
#      case 3:  jugador="tijera"; break;
#         exit(1);
#   }
# /////
# /*asignar valor a computadora*/
# switch (num) {
#     case 1:  computadora="piedra"; break;
#     case 2:  computadora="papel"; break;
#      case 3:  computadora="tijera"; break;
#         exit(1);
#   }
# //////////////////////
# if(strcmp(jugador,"piedra")==0 && strcmp(computadora,"tijera")==0){
#   printf("mi respuesta es%s\n tu respuesta es %s\n Es un empate",computadora, jugador);
#       printf("Haz ganado");
# }
# if(strcmp(jugador,"tijeras")==0 && strcmp(computadora,"papel")==0){
#   printf("mi respuesta es%s\n tu respuesta es %s\n ",computadora, jugador);
#       printf("Haz ganado");
# }
# else if(strcmp(jugador,"papel")==0 && strcmp(computadora,"piedra")==0){
#   printf("mi respuesta es %s\n tu respuesta es %s\n ",computadora, jugador);
#       printf("Haz ganado");
# }
#   else if(strcmp(jugador,computadora)==0){
#     printf("mi respuesta es %s\n tu respuesta es %s\n ",computadora, jugador);
#       printf("Es un empate");
#   }
#             else{
#             printf("mi respuesta es %s\n tu respuesta es %s\n ",computadora, jugador);
#               printf("Haz perdido");
#           }
# return 0;
# }
#
# int main() {
#   printf("Hola como estas jugamos piedra papel y tijeras?\n");
#    printf("Introduce 1 para SI Y 2 para NO \n");
#      int res, num;
#      int seleccion;
#     scanf("%d", &res);
#
#     if(res==1){
#         printf("Juguemos :D\n");
#             printf("PIEDRA, PAPEL O TIJERA \n");
#              printf("Introduce 1 ===>PIEDRA \n");
#              printf("Introduce 2 ===>PAPEL \n");
#              printf("Introduce 3 ===>TIJERA \n");
#             scanf("%d", &seleccion);
#                num= rand()%3;//asignar valor a computadora
#             juego(seleccion, num);
#     }
#     else {
# printf("Juguemos en otro momento, BYE!, :D");
#     }
#   return 0;
# }
# ~~~
#
# ### 5. Write a program that display the Zodiacal Sign using the day and month of birth.
# ~~~
# #include<stdio.h>
# #include<stdlib.h>
#
# /*Instructions:Ingress your birth day and ingress the number of your birth month*/
#
# int main(){
#
#     int month;
#     int day;
#
#     printf("What day were you born?: "); //getting born day
#     scanf("%d",&day);
#
#     printf("\n");
#
#     printf("What month number were you born?: "); //getting born month
#     scanf("%d",&month);
#
#     printf("\n");
#
#     switch(month){
#
#         case 1://January
#             if (day >= 1 && day <=19){ //First part of January
#                 printf("Your Zodiac Sign is Capricorn\n");
#             }
#             if (day >=20 && day <=31){//Second part of January
#                 printf("Your Zodiac Sign is Aquarium\n");
#             }
#             break;
# //why 2 if? Because is it important define well the date to don't make errors
# //If we were put if-else, you will have Zodiac Signs to days that does not exist.
#
#         case 2://February
#             if (day >= 1 && day <=19){
#                 printf("Your Zodiac Sign is Aquarium\n");
#             }
#             if (day >=20 && day <=29){
#                 printf("Your Zodiac Sign is Pisces\n");
#             }
#             break;
#
#         case 3://March
#             if (day >=1  && day <=20){
#                 printf("Your Zodiac Sign is Pisces\n");
#             }
#             if (day >=21 && day <=31){
#                 printf("Your Zodiac Sign is Aries\n");
#             }
#             break;
#
#         case 4://April
#             if (day >=1  && day <=19){
#                 printf("Your Zodiac Sign is Aries\n");
#             }
#             if (day >=20 && day <=30){
#                 printf("Your Zodiac Sign is Taurus\n");
#             }
#             break;
#
#         case 5://May
#             if (day >=1  && day <=20){
#                 printf("Your Zodiac Sign is Taurus\n");
#             }
#             if (day >=21 && day <=31){
#                 printf("Your Zodiac Sign is Gemini\n");
#             }
#             break;
#
#         case 6://June
#             if (day >=1  && day <=20){
#                 printf("Your Zodiac Sign is Gemini\n");
#             }
#             if (day >=21 && day <=30){
#                 printf("Your Zodiac Sign is Cancer\n");
#             }
#             break;
#
#         case 7://July
#             if (day >=1  && day <=22){
#                 printf("Your Zodiac Sign is Cancer\n");
#             }
#             if (day >=23 && day <=31){
#                 printf("Your Zodiac Sign is Leo\n");
#             }
#             break;
#
#         case 8://August
#             if (day >=1  && day <=22){
#                 printf("Your Zodiac Sign is Leo\n");
#             }
#             if (day >=23 && day <=31){
#                 printf("Your Zodiac Sign is Virgo\n");
#             }
#             break;
#
#         case 9://September
#             if (day >=1  && day <=22){
#                 printf("Your Zodiac Sign is Virgo\n");
#             }
#             if (day >=23 && day <=30){
#                 printf("Your Zodiac Sign is Libra\n");
#             }
#             break;
#
#         case 10://October
#             if (day >=1  && day <=22){
#                 printf("Your Zodiac Sign is Libra\n");
#             }
#             if (day >=23 && day <=31){
#                 printf("Your Zodiac Sign is Scorpio\n");
#             }
#             break;
#
#         case 11://November
#             if (day >=1  && day <=21){
#                 printf("Your Zodiac Sign is Scorpio\n");
#             }
#             if (day >=22 && day <=30){
#                 printf("Your Zodiac Sign is Sagittarius\n");
#             }
#             break;
#
#         case 12://December
#             if (day >=1  && day <=21){
#                 printf("Your Zodiac Sign is Sagittarius\n");
#             }
#             if (day >=22 && day <=31){
#                 printf("Your Zodiac Sign is Capricorn\n");
#             }
#             break;
#     }
# return 0;
# }
# ~~~
# ___
#
# ## Python excercises
#
# ### 1. Calculate the Euler constant e using the series.
# ~~~
# def fact(n):# we get the factorial of the number by making a function
#     if n == 0:
#         r = 1
#     else:
#         r = n * fact(n - 1)
#     return r
#
#
# num=int(input("Enter the number of terms: "))#asking for a number
# sum1=1
#
# for i in range(1,num+1):
#     sum1=sum1+(1/fact(i))
# print("The eulers is",round(sum1,4))# control the number of digits you want them to see
# ~~~
#
# ### 2. Given a list of strings delete all special chars in each one (non-alphanumeric chars).
# ~~~
# import re
#
# frase=input("Enter the string: ")
#
# #the list function creates a list consisting of the iterable elements for example hola = h, o, l, a
# valores = list([letra for letra in frase
#                if letra.isalpha() or letra.isnumeric()])
#                #isisalpha () checks if it is a letter
#                #isnumeric () verify that it is a number
#
# r = "".join(valores)# The join function converts a list into a string made up of the list elements separated by commas, so it joins all the variables previously separated with list
#
# print ("final string", r)
# ~~~
#
# ### 3. Check the validity of a password (input from users).
# #### Validation:
# - At least 1 letter between [a-z] and 1 letter between [A-Z].
# - At least 1 number between [0-9].
# - At least 1 at least one punctuation sign.
# - Minimum length 6 characters. • Maximum length 16 characters.
#
# ~~~
# import re
#
# #We create a function to do the validation
# def validation(password):
#   if 6<= len(password) <=16: #Fisrt condition
#     if re.search('[a-z]',password) and re.search('[A-Z]',password): #Second Condition
#       if re.search('[.#_]',password): #Third condition
#         if re.search('[0-9]',password): #Forth condition
#           print("Password accepted")
#         else:
#           print("Password not accepted")
#       else:
#         print("Password not accepted")
#     else:
#        print("Password not accepted")
#   else:
#     print("Password not accepted")
#
# pw=input("Enter your password: ") #User part
# print(validation(pw)) #We use the function
#
# #Help from John Ortiz Ordonez
# ~~~
#
#
# ### 4. Count the Word Frequency in a Text (Unique String). Don’t forget to: normalize to lower case and delete special chars.
# ~~~
# import re
# #cadena = 'i2t was the best of times it was the worst of times *?/'
# cadena=input("Enter the string: ")
# #cadenaPalabras += 'it was the age of wisdom it was the age of foolishness'
# cadenaPalabras = re.sub('[^a-zA-Z \n\.]', '', cadena)
# # dejamos solo las letras con sub
# listaPalabras = cadenaPalabras.split()
# #convierte una lista en una cadena formada por los elementos de la lista separados por comas
#
# frecuenciaPalab = []
# for w in listaPalabras:
#     frecuenciaPalab.append(listaPalabras.count(w))
#     #.count Divide una cadena en una lista donde cada palabra es un elemento de la lista
#      #.append agrega los valores a nueva lista
#
#
# print("Cadena\n" + cadenaPalabras +"\n")
#
#
# print("Palabras\n" + str(list(zip(listaPalabras, frecuenciaPalab))))
# # zip toma como argumento dos o más objetos iterables ( y retorna un nuevo iterable en este caso el numero de palabras repetidas
# #list ordenada un conjunto
# #str une las listas y las imprime
# ~~~
#
# ### 5. Compute the Matrix Multiplication between a matrix A and B. Don’t use any library.
# ~~~
# mat1=[]
# mat2=[]
# matr=[]
# #We entered the size of matrix 1
# print("First Matrix")
# fmat1=int(input("Rows: "))
# cmat1=int(input("Columns: "))
# #We entered the size of matrix 2
# print("\nSecond Matrix")
# fmat2=int(input("Rows: "))
# cmat2=int(input("Columns: "))
# #Verification
# if cmat1!=fmat2:
#   print("Error")
# else:
#   #We enter the elements of matriz1
#   print("\n")
#   for z in range(0,fmat1):
#     mat1.append([0]*cmat1)
#   for i in range(0,fmat1):
#     for j in range(0,cmat1):
#       mat1[i][j]= int(input("Matrix 1[%d][%d]: "%(i,j)))
#   print("\n X \n")
#   #We enter the elements of matriz2
#   for z in range(0,fmat2):
#     mat2.append([0]*cmat2)
#   for i in range(0,fmat2):
#     for j in range(0,cmat2):
#       mat2[i][j]= int(input("Matrix 2[%d][%d]: "%(i,j)))
#
#   #We create the new matrix
#   for k in range(0,fmat1):
#     matr.append([0]*cmat2)
#     for j in range(0,cmat2):
#       matr[k][j]=0
#   for i in range(0,fmat1):
#     for j in range(0,cmat1):
#       for k in range(0,cmat2):
#         matr[i][k]+= mat1[i][k]*mat2[j][k]
#   print("\n = \n")
#
#   #We print the result
#   print("New Matrix\n")
#   x=""
#   for i in range(0,fmat1):
#     for k in range(0,cmat2):
#       x+=str(matr[i][k])+'\t'
#   print (x)
#   x=""
#  ~~~
#   ___
