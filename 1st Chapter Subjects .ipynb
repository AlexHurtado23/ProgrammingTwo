# %% [markdown]
# # 1st Chapter Subjects
#
# ### Team:
#
# * Emmanuel Alejandro Hurtado Alejandre    [https://github.com/AlexHurtado23/ProgrammingTwo]
#
# * Pedro Alejandro Uicab Díaz              [https://github.com/PedroAlejandroUicabDiaz/UNIT1_DATOS_2A.git]
#
#
# ## Classification of programming paradigms
# ___
#
# ### Concept of programming paradigm
#
# blablaba
#
# ___
#
#
#
# ___
#
#
# ## Data Representations and Operators
#
# ___
#
# ### Programming languages
#
# A programming language is a computer language programmers use to develop software programs, scripts, or other sets of instructions for computers to execute.
#
# Although many languages share similarities, each has its own syntax. Once a programmer learns the languages rules, syntax, and structure, they write the source code in a text editor or IDE. Then, the programmer often compiles the code into machine language that can be understood by the computer. Scripting languages, which do not require a compiler, use an interpreter to execute the script.
# ___
#
#
# ### Sequential algorithms
#
# They are algorithms that is executed sequentially – once through, from start to finish, without other processing executing – as opposed to concurrently or in parallel. These algorithms are usually presented as flowcharts and are the most basic algorithms for programmers when they start programming.
# ___
#
#
# ### Source code
#
# Source code is the list of human-readable instructions that a programmer writes—often in a word processing program—when he is developing a program. The source code is run through a compiler to turn it into machine code, that a computer can understand and execute. Machine code consists primarily of 1s and 0s, so it isn't human-readable.
#
# Source code and Machine code are the before and after states of a computer program that is compiled. Programming languages that compile their code include C, C++ or Fortran.
#
# Example:
#
#     #include<stdio.h>
#     int main (){
#
#         printf("Hello World!");
#
#     return 0;
#     }
# ___
#
#
# ### Data representatoin in structured programming language:
#
# #### Identifiers
# We use them to name various elements of a program, such as variables, functions, and arrays. An identifier is made up of the 27 letters of the alphabet, including capital letters. Also we can use digits from 0 until 9 and the underscore (_).
#
# The restrictions are that at the first character must be a letter; symbols like #, -, *,  , are not permited. Its recommendable to have clear and simple names as much as posible.
#
# #### Variables
# A variable is the space in memory that we reserve in order to store data, whether known or unknown. When the execution of the program begins, these may change.
#
# To declare a variable, it is necessary that we put the data type and its identifier; if we know its value we can initialize it from the beginning.
#
# Sintax for every type of variable is the next:  ```int Integer = 10;```
#
# #### Constants
# A constant is a memory space that is generally reserved for a value that will NEVER change during the execution of the program, it is usually declared in the program header in the following way:
#
# Symbolic constant:
#
#     #define greeting = "Hello There";
#
# Numeric constant:
#
#     #const float Pi = 3.1416;
#
# #### Reserved Words
# Are words that already have a predeterminated function on the programming language. For example in C we have the following reserved words:
#
# |Reserved|words|in|C|
# |----|------|---|------|
# |auto|double|int|struct|
# |break|else|long|switch|
# |case|enum|register|typedef|
# |char|extern|return|union|
# |const|float|short|unsigned|
# |continue|for|signed|void|
# |default|goto|sizeof|volatile|
# |do|if|static|while|
#
# #### Types of data, Memory space and Range values
#
# |Primitive data type|Description|Memory space|Range value|
# |-------------------|-----------|------------|-----------|
# |int|It defines an integer value.|2 bytes|-32,767 to 32,768|
# |char|It keeps a character, can be a value or sign.|1 byte|-128 to 127|
# |float|It defines a float, number with decimals.|4 bytes|3.4x10^-38 to 3.4x10^38|
# |double|It defines a float but much bigger.|8 bytes|1.7x10^-308 to 1.7x10^308|
#
#
# |Composites data type|Description|Memory space|Range value|
# |-------------------|-----------|------------|-----------|
# |void|NULL value|0 bytes| NULL|
# |unsigned char|It keeps a character or value without sign.|1 byte|0 to 255|
# |unsigned int|It defines an integer value without sign.|2 bytes|0 to 65,535|
# |short int|It defines an short integer.|2 bytes|-32,767 to 32,768|
# |long|It defines an iterger but much bigger.|4 bytes|-2,147,483,648 to 2,147,483,647|
# |unsigned long|It defines a big integer without sign.|4 bytes|0 to 4,249,967,295|
# |long double|It increments the size of double.|10 bytes|3.4x10^-4932 to 1.1x10^4932|
#
#
# #### Data type conversion
#
# Explicit conversions is known as type casting or, type-conversion.
# This is done to take advantage of certain features of type hierarchies or type representations. It helps us to compute expressions containing variables of different data types.
#
# You can convert the values from one type to another explicitly using the cast operator as follows:
# (type_name) expression
#
# Example:
#
#     #include<stdio.h>
#     int main()
#     {
#         double x = 1.2;
#
#         // Explicit conversion from double to int
#         int sum = (int)x + 1;
#
#         printf("sum = %d", sum);
#
#         return 0;
#     }
# output: sum = 2
#
#
# Implicit conversions are implicitly performed to cast their values to a common type. The compiler first performs integer promotion; if the operands still have different types, then they are converted to the type that appears highest in the following hierarchy:
#
# bool -> char -> short int -> int -> unsigned int -> long -> unsigned long -> long long -> unsigned long long -> float -> double -> long double
#
# Example:
#
#     #include<stdio.h>
#     int main()
#     {
#         int x = 10;    // integer x
#         char y = 'a';  // character c
#
#         // y implicitly converted to int. ASCII
#         // value of 'a' is 97
#         x = x + y;
#
#         // x is implicitly converted to float
#         float z = x + 1.0;
#
#         printf("x = %d, z = %f", x, z);
#         return 0;
#     }
# output: x = 107, z = 108.000000
#
# ___
#
#
# ### Operators of structured programming language
#
# #### Arithmetic
#
# |Operator|Operation|Type of data|
# |--------|---------|------------|
# |+|Addition|Integers and Reals|
# |-|Substraction|Integers and Reals|
# |*|Multiplication|Integers and Reals|
# |/|Division|Integers and Reals|
# |%|Residue|Integers|
#
# #### Conditional
#
# The conditional operator ? : produces a result. In the expression E1? E2: E3, E1 is a relational expression that is evaluated first. If the result is true, then E2 is evaluated and this is the result. Otherwise (if E1 is false), then E3 is evaluated and this is the result. Note that if premise E1 is true, then expression E3 fails to evaluate.
#
# The operator ? : can be used to replace certain if-then-else statements, although it can lead to more compact expressions than the corresponding if ... else expressions.
#
# #### Logical
#
# |Operator|Description|
# |--------|---------|
# |&&|And: the result of an operation and logic will be true if both statements are ture, if not it will be false.|
# |Logical Or|The result of an operation or logic will be true if al least one statement is true, if both are not, it will be false.|
# |!|Not: the result of an operation no logic only will be true if the statements are false.|
#
# #### Relationship
#
# |Operator|Description|
# |--------|---------|
# |<|smaller than|
# |<=|smaller or equal than|
# |>|bigger than|
# |>=|bigger or equal than|
# |==|equal and only equal|
# |!=|other than|
#
# ___
#
# ### Basic functions of input-output (I/O) in structured programming language
#
# #### Input
#
# One way to ingress data into a program is through the function scanf(). it will keep the typed value in the variable var.
#
# ```scanf(%d,&var);```
#
# Example:
#
#     #include<stdio.h>
#
#     int main(){
#
#         int age;
#         float height;
#
#         printf("type your age");
#         scanf(%d,&age);
#
#         printf("type your height");
#         scanf(%f,&height);
#
#         printf("you are %d years old and your height is %f m",age,height);
#
#     return 0;
#     }```
#
# output: you are 20 years old and your height is 1.87 m
#
#
# #### Output
#
# One way to show data to the user is through the function printf(). It will print on the screan the integer value of result.
#
# ```printf("the result of the sum is %d", result);```
#
# Type control chains for output
#
# |Chain|Description|
# |-----|-----------|
# |%d|Data is a decimal integer.|
# |%i|Data is an integer.|
# |%o|Data is a octal integer.|
# |%x|Data is a hexadecimal.|
# |%u|Data is an unsigned integer.|
# |%c|Data is a character.|
# |%e|Data is a real number expresed in base and exponent.|
# |%f|Data is a float number.|
# |%g|Data is a real number.|
# |%s|Data is a character chain.|
# |%lf|Data is a real long double.|
#
# Scape sequences
#
# |Scape sequence|Description|
# |--------------|-----------|
# |\a|Alarm|
# |\b|Recoil|
# |\f|Page advance|
# |\n|Return and advance line|
# |\r|Return|
# |\t|Tab|
# |\v|Vertical tab|
# |\\|Inverted diagonal|
# |\?|Question mark|
# |\'|Double quotation marks|
# |\000|Octal|
# |\xhh|Hexadecimal|
# |\0|NULL character|
#
# ___
#
#
# ## Version control
#
# ### Distributed version control
#
# A distributed version control system is a type of version control where the complete codebase, including its full version history, is mirrored on every developer's computer. It's abbreviated DVCS. A great example of DVCS is GitHub.
#
# Changes to files are tracked between computers. For example, my workstation and yours. In the beginning, this required specific coordination strategies to maintain consistency in projects, so all the developers could keep track of what was happening to files at any given time.
#
# Some benefits of the distribuited version systems are:
# * Branching and merging can happen automatically and quickly.
# * Developers have the ability to work offline.
# * Multiple copies of the software eliminate reliance on a single backup.
# * The increase in developer productivity.
# * it makes common activities quick: check in, check out, and commit.
#
#
# ___
#
#
# ## References
#
# * Introducccion a la programacion estructurada en C.pdf
# * https://www.geeksforgeeks.org/type-conversion-c/
# * https://www.zator.com/Cpp/E4_9_6.htm
# * https://www.thoughtco.com/source-code-definition-958200
# * https://www.encyclopedia.com/computing/dictionaries-thesauruses-pictures-and-press-releases/sequential-algorithm
# * https://www.perforce.com/blog/vcs/what-dvcs-anyway
